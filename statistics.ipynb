# %%
import pandas as pd

# %%
col_names = ['Tiempo medio en atracar', 'Tiempo maximo en atracar', 'Media de barcos en muelles', 'Media tiempo de espera en la entrada','Maximo tiempo de espera en la entrada','Media de barcos esperando en la entrada','Maximo de barcos esperando en la entrada','Tiempo total de simulacion']

df = pd.read_csv("output-20-13.txt", names=col_names, sep=' ')
df.head()
# Out:
#    Tiempo medio en atracar  Tiempo maximo en atracar  \
# 0                    12.22                    113.02
# 1                    14.30                     90.09
# 2                    13.73                     94.01
# 3                    14.31                    129.63
# 4                    13.66                     90.56
#
#    Media de barcos en muelles  Media tiempo de espera en la entrada  \
# 0                       12.44                                  2.27
# 1                       13.02                                  4.39
# 2                       12.74                                  3.81
# 3                       11.46                                  3.83
# 4                       12.39                                  3.75
#
#    Maximo tiempo de espera en la entrada  \
# 0                                  92.36
# 1                                  86.10
# 2                                  76.74
# 3                                 103.70
# ...

# %%
statistics = df.describe()
statistics
# Out:
#        Tiempo medio en atracar  Tiempo maximo en atracar  \
# count               200.000000                200.000000
# mean                 15.631750                112.646300
# std                   3.410248                 34.120006
# min                  10.470000                 49.030000
# 25%                  13.260000                 87.972500
# 50%                  14.630000                108.120000
# 75%                  17.135000                134.967500
# max                  28.280000                216.150000
#
#        Media de barcos en muelles  Media tiempo de espera en la entrada  \
# count                  200.000000                            200.000000
# mean                    12.584000                              5.620950
# std                      0.544147                              3.433812
# min                     11.140000                              0.400000
# 25%                     12.217500                              3.247500
# ...

# %%
print("Media para todas las métricas:")
statistics.iloc[1]
# Out:
# Media para todas las métricas:
# Tiempo medio en atracar                        15.63175
# Tiempo maximo en atracar                      112.64630
# Media de barcos en muelles                     12.58400
# Media tiempo de espera en la entrada            5.62095
# Maximo tiempo de espera en la entrada          96.12100
# Media de barcos esperando en la entrada         0.59085
# Maximo de barcos esperando en la entrada       13.28000
# Tiempo total de simulacion                  10468.41260
# Name: mean, dtype: float64

# %%
df.hist(['Tiempo medio en atracar','Media tiempo de espera en la entrada', 'Media de barcos esperando en la entrada', 'Tiempo total de simulacion'], bins=50, figsize=(15,10), color='orange')
# Out:
# array([[<AxesSubplot:title={'center':'Tiempo medio en atracar'}>,
#         <AxesSubplot:title={'center':'Media tiempo de espera en la entrada'}>],
#        [<AxesSubplot:title={'center':'Media de barcos esperando en la entrada'}>,
#         <AxesSubplot:title={'center':'Tiempo total de simulacion'}>]],
#       dtype=object)
